# %%
import pymongo

# %%
client = pymongo.MongoClient('localhost', 27017)

# %%
db = client['chapter3']

# %%
collection = db['income']

# %%
with open('data/income_header.txt') as f_in:
    columns_headings = f_in.readline()

# %%
columns_headings
# Out:
# 'age,workclass,fnlwgt,education,education-num,marital-status,occupation,relationship,race,sex,capital-gain,capital-loss,hours-per-week,native-country,label'

# %%
columns_headings_list = columns_headings.split(',')

# %%
columns_headings_list
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'label']

# %%
row_dict_list = list()
with open('data/income.txt') as f_in:
    for line in f_in:
        row_list = line.rstrip('\n').split(',')
        row_dict = dict(zip(columns_headings_list, row_list))
        row_dict_list.append(row_dict)
        collection.insert_one(row_dict)

# %%
collection.count() # should be = 32562
# Out:
# <ipython-input-33-ac4899ba2df1>:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   collection.count() # should be = 32562
# 32562
